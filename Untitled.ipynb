# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. 데이터 불러오기

# %%
df = pd.read_csv('C:/Users/82104/Desktop/show.csv', engine='python')
df
# Out:
#         순번                          제목       시작일       종료일  \
# 0     2646                 프로야구(롯데:두산)  20210625  20210627
# 1     2645                 프로야구(키움:두산)  20210622  20210624
# 2     2644                 프로야구(삼성:두산)  20210615  20210617
# 3     2643                프로야구(SSG:두산)  20210604  20210606
# 4     2642                 프로야구(KT:LG)  20210629  20210701
# ...    ...                         ...       ...       ...
# 1155     7           잠실 종합운동장에서 열리는 영화  20130708  20130711
# 1156     5  더 웹툰: 예고살인 올림픽 주경기장에서 열리는   20130716  20130717
# 1157     3      감시자들-잠실보조경기장에서 영화를 봅시다  20130710  20130711
# 1158     2                  은밀하게 위대하게   20130619  20130621
# 1159     1                          제목  20130701  20130701
#
#                                              이용시간    이용연령    이용대상  \
# 0     6월 25일(금) 18시 30분 6월 26일(토) ~ 6월 27일(일) 17시  전체 관전가  전체 관전가
# 1                  6월 22일(화) ~ 6월 24일(목)  18시 30분  전체 관전가  전체 관전가
# ...

# %%
df_1 = df.drop(columns=['이용료', '이용시간', '이용연령', '이용대상','링크 URL','수정일','순번','시작일','종료일','등록일'])

# %%
df_1
# Out:
#                               제목  분야코드  시설코드    분야명      시설명
# 0                    프로야구(롯데:두산)     1     8  스포츠경기    잠실야구장
# 1                    프로야구(키움:두산)     1     8  스포츠경기    잠실야구장
# 2                    프로야구(삼성:두산)     1     8  스포츠경기    잠실야구장
# 3                   프로야구(SSG:두산)     1     8  스포츠경기    잠실야구장
# 4                    프로야구(KT:LG)     1     8  스포츠경기    잠실야구장
# ...                          ...   ...   ...    ...      ...
# 1155           잠실 종합운동장에서 열리는 영화     1     5  스포츠경기  잠실종합운동장
# 1156  더 웹툰: 예고살인 올림픽 주경기장에서 열리는      1     6  스포츠경기  올림픽주경기장
# 1157      감시자들-잠실보조경기장에서 영화를 봅시다     1     7  스포츠경기  잠실보조경기장
# 1158                  은밀하게 위대하게      3    13    이벤트  목동실내빙상장
# 1159                          제목     2    11     공연   목동주경기장
#
# [1160 rows x 5 columns]

# %% [markdown]
# ## 2. 데이터 탐색하기

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1160 entries, 0 to 1159
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   제목      1160 non-null   object
#  1   분야코드    1160 non-null   int64
#  2   시설코드    1160 non-null   int64
#  3   분야명     1160 non-null   object
#  4   시설명     1160 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 45.4+ KB

# %%
df_1['분야코드'].value_counts()
# Out:
# 1    938
# 2    162
# 4     45
# 3     15
# Name: 분야코드, dtype: int64

# %%
df_1['시설명'].value_counts()
# Out:
# 잠실야구장         497
# 잠실실내체육관       279
# 올림픽주경기장       119
# 목동야구장         118
# 목동주경기장         59
# 잠실종합운동장        36
# 잠실보조경기장        25
# 목동실내빙상장        24
# 잠실종합운동장 광장      3
# Name: 시설명, dtype: int64

# %%
df_1['분야명'].value_counts()
# Out:
# 스포츠경기    938
# 공연       162
# 기타        45
# 이벤트       15
# Name: 분야명, dtype: int64
