# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns',None)

# %%
df = pd.read_csv('기상정보활용올림픽공원이용분석정보.csv')

# %%
df
# Out:
#        MESURE_DE MESURE_WKDAY_NM WKEND_AT  MESURE_HOUR  \
# 0       20120107             토요일        Y            0
# 1       20120107             토요일        Y            1
# 2       20120107             토요일        Y            2
# 3       20120107             토요일        Y            3
# 4       20120107             토요일        Y            4
# ...          ...             ...      ...          ...
# 85152   20211026             화요일        N           21
# 85153   20211026             화요일        N           22
# 85154   20211026             화요일        N           23
# 85155   20211027             수요일        N            0
# 85156   20211027             수요일        N            1
#
#        CRRSPND_TIME_ISE_ENTVHCL_CO  CRRSPND_TIME_ISE_LVVHCL_CO  \
# 0                                0                           0
# 1                                0                           0
# 2                                0                           0
# ...

# %% [markdown]
# ## Column 정보
#
# - MESURE_DE	: 측정 일자
# - MESURE_WKDAY_NM : 측정 요일 명
# - WKEND_AT:주말 여부
# - MESURE_HOUR:측정 시
# - CRRSPND_TIME_ISE_ENTVHCL_CO:해당 시간 내 입차수
# - CRRSPND_TIME_ISE_LVVHCL_CO:해당 시간 내 출차수
# - CRRSPND_TIME_ISE_N2GT_LVVHCL_CO: 해당 시간 내 북2문 출차수
# - CRRSPND_TIME_ISE_W1GT_LVVHCL_CO: 해당 시간 내 서1문 출차수
# - CRRSPND_TIME_ISE_W2GT_LVVHCL_CO: 해당 시간 내 서2문 출차수
# - CRRSPND_TIME_ISE_S2GT_LVVHCL_CO: 해당 시간 내 남2문 출차수
# - CRRSPND_TIME_ISE_S3GT_LVVHCL_CO: 해당 시간 내 남3문 출차수
# - CRRSPND_TIME_ISE_S4GT_LVVHCL_CO: 해당 시간 내 남4문 출차수
# - CRRSPND_TIME_ISE_E2GT_LVVHCL_CO: 해당 시간 내 동2문 출차수
# - MESURE_TP_VALUE: 측정 온도 값
# - PRCPT_STLE_CD: 강수 형태 코드
# - PRCPT_STLE_NM: 강수 형태 명
# - TIME_ISE_PRCPTTN_QY: 시간 내 강수량양
# - MESURE_HD_VALUE: 측정 습도 값
# - MESURE_PBLMRL_VALUE: 측정 풍속 값
# - MESURE_WD_VALUE: 측정 풍향 값
# - WD_FLAG_N: 풍향 구분명
