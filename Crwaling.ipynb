# %%
import requests
from bs4 import BeautifulSoup
import bs4
import csv
import pprint
import pandas as pd
from pandas import DataFrame
from datetime import datetime, timedelta

# %%
datas = []
# 각 행의 컬럼, 이름, 값을 가지는 리스트 만들기
seatcnt_list = [] # 좌석 수 리스트
totnmrs_list = [] # 티켓 판매 수 리스트

# %%
start = "20170801"
last = "20170810"
start_date = datetime.strptime(start, "%Y%m%d")
last_date = datetime.strptime(last, "%Y%m%d")

# %% [markdown]
# ## 예술의전당

# %%
#인증키 입력
encoding ='3618439972f548dd99831f9a6e4856e1' #발급받은 인코딩키 입력
# 종료일 까지 반복
while start_date <= last_date:
    string = str(start_date.year)
    if (start_date.month<10):
        string = string + str(0)
        string = string + str(start_date.month)
    else:
        string = string + str(start_date.month)
    if (start_date.day<10):
        string = string + str(0)
        string = string + str(start_date.day)
    else:
        string = string + str(start_date.day)
    print(string)
    #url 입력
    url = 'https://www.kopis.or.kr/openApi/restful/prfstsPrfByFct?'
    params ={'service' : encoding , 'cpage' : '1', 'rows' : '10', 'stdate' : string, 'eddate' : string,'sharea':'11','shprfnmfct':'예술의전당' }

    response = requests.get(url, params=params)

    content = response.text

    xml_obj = bs4.BeautifulSoup(content,'lxml-xml')
    rows = xml_obj.findAll('prfst')
    print(rows)

    # xml 안의 데이터 수집
    for item in rows:
        seatcnt = item.find('seatcnt') #좌석 수
        seatcnt = seatcnt.get_text()
        totnmrs = item.find('totnmrs') #총 티켓 판매 수
        totnmrs = totnmrs.get_text()
        data = [seatcnt,totnmrs]
        datas.append(data)

    df = pd.DataFrame(datas, columns=['좌석 수', '티켓 판매수'])
    start_date += timedelta(days=1)
# Out:
# 20170801
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>CJ 토월극장</prfnmplc>
# <prfnmfct>CJ 토월극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>354</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>리사이틀홀</prfnmplc>
# <prfnmfct>리사이틀홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>2527</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>콘서트홀</prfnmplc>
# <prfnmfct>콘서트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>241</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>412</totnmrs>
# <prfdtcnt>2</prfdtcnt>
# <prfnmplc>자유소극장</prfnmplc>
# <prfnmfct>예술의전당</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>600</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>IBK챔버홀</prfnmplc>
# <prfnmfct>IBK챔버홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>2283</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>1011</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>오페라극장</prfnmplc>
# <prfnmfct>예술의전당</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>신세계스퀘어 야외무대</prfnmplc>
# <prfnmfct>신세계스퀘어 야외무대</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>130</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>인춘아트홀</prfnmplc>
# <prfnmfct>인춘아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>1101어린이라운지</prfnmplc>
# <prfnmfct>1101어린이라운지</prfnmfct>
# </prfst>]
# 20170802
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>CJ 토월극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>CJ 토월극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>354</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>리사이틀홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>리사이틀홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>2527</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>콘서트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>콘서트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>241</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>453</totnmrs>
# <prfnmplc>자유소극장</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>예술의전당</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>600</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>IBK챔버홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>IBK챔버홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>2283</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>915</totnmrs>
# <prfnmplc>오페라극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>예술의전당</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>신세계스퀘어 야외무대</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>신세계스퀘어 야외무대</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>130</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>인춘아트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>인춘아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>1101어린이라운지</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>1101어린이라운지</prfnmfct>
# </prfst>]
# 20170803
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>CJ 토월극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>CJ 토월극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>354</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>리사이틀홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>리사이틀홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>2527</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>콘서트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>콘서트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>241</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>401</totnmrs>
# <prfnmplc>자유소극장</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>예술의전당</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>600</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>IBK챔버홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>IBK챔버홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>2283</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>945</totnmrs>
# <prfnmplc>오페라극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>예술의전당</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>신세계스퀘어 야외무대</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>신세계스퀘어 야외무대</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>130</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>인춘아트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>인춘아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>1101어린이라운지</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>1101어린이라운지</prfnmfct>
# </prfst>]
# 20170804
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>738</totnmrs>
# <prfnmplc>CJ 토월극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>예술의전당</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>354</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>리사이틀홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>리사이틀홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>2527</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>콘서트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>콘서트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>241</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>386</totnmrs>
# <prfnmplc>자유소극장</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>예술의전당</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>600</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>IBK챔버홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>IBK챔버홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>2283</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>1069</totnmrs>
# <prfnmplc>오페라극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>예술의전당</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>신세계스퀘어 야외무대</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>신세계스퀘어 야외무대</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>130</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>인춘아트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>인춘아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>1101어린이라운지</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>1101어린이라운지</prfnmfct>
# </prfst>]
# 20170805
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>747</totnmrs>
# <prfnmplc>CJ 토월극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>예술의전당</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>354</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>리사이틀홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>리사이틀홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>2527</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>콘서트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>콘서트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>241</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>357</totnmrs>
# <prfnmplc>자유소극장</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>예술의전당</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>600</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>IBK챔버홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>IBK챔버홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>2283</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>1733</totnmrs>
# <prfnmplc>오페라극장</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>예술의전당</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>신세계스퀘어 야외무대</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>신세계스퀘어 야외무대</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>130</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>인춘아트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>인춘아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>1101어린이라운지</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>1101어린이라운지</prfnmfct>
# </prfst>]
# 20170806
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>785</totnmrs>
# <prfnmplc>CJ 토월극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>예술의전당</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>354</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>리사이틀홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>리사이틀홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>2527</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>콘서트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>콘서트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>241</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>286</totnmrs>
# <prfnmplc>자유소극장</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>예술의전당</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>600</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>IBK챔버홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>IBK챔버홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>2283</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>2023</totnmrs>
# <prfnmplc>오페라극장</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>예술의전당</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>신세계스퀘어 야외무대</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>신세계스퀘어 야외무대</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>130</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>인춘아트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>인춘아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>1101어린이라운지</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>1101어린이라운지</prfnmfct>
# </prfst>]
# 20170807
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>CJ 토월극장</prfnmplc>
# <prfnmfct>CJ 토월극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>354</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>353</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>리사이틀홀</prfnmplc>
# <prfnmfct>예술의전당</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>2527</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>1583</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>콘서트홀</prfnmplc>
# <prfnmfct>예술의전당</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>241</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>자유소극장</prfnmplc>
# <prfnmfct>자유소극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>600</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>IBK챔버홀</prfnmplc>
# <prfnmfct>IBK챔버홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>2283</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>오페라극장</prfnmplc>
# <prfnmfct>오페라극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>신세계스퀘어 야외무대</prfnmplc>
# <prfnmfct>신세계스퀘어 야외무대</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>130</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>인춘아트홀</prfnmplc>
# <prfnmfct>인춘아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>1101어린이라운지</prfnmplc>
# <prfnmfct>1101어린이라운지</prfnmfct>
# </prfst>]
# 20170808
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>CJ 토월극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>CJ 토월극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>354</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>리사이틀홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>리사이틀홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>2527</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>콘서트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>콘서트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>241</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>289</totnmrs>
# <prfnmplc>자유소극장</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>예술의전당</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>600</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>423</totnmrs>
# <prfnmplc>IBK챔버홀</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>예술의전당</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>2283</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>768</totnmrs>
# <prfnmplc>오페라극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>예술의전당</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>신세계스퀘어 야외무대</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>신세계스퀘어 야외무대</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>130</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>인춘아트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>인춘아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>1101어린이라운지</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>1101어린이라운지</prfnmfct>
# </prfst>]
# 20170809
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>CJ 토월극장</prfnmplc>
# <prfnmfct>CJ 토월극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>354</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>리사이틀홀</prfnmplc>
# <prfnmfct>리사이틀홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>2527</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>2097</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>콘서트홀</prfnmplc>
# <prfnmfct>예술의전당</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>241</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>299</totnmrs>
# <prfdtcnt>2</prfdtcnt>
# <prfnmplc>자유소극장</prfnmplc>
# <prfnmfct>예술의전당</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>600</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>IBK챔버홀</prfnmplc>
# <prfnmfct>IBK챔버홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>2283</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>811</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>오페라극장</prfnmplc>
# <prfnmfct>예술의전당</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>신세계스퀘어 야외무대</prfnmplc>
# <prfnmfct>신세계스퀘어 야외무대</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>130</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>인춘아트홀</prfnmplc>
# <prfnmfct>인춘아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>1101어린이라운지</prfnmplc>
# <prfnmfct>1101어린이라운지</prfnmfct>
# </prfst>]
# 20170810
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>CJ 토월극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>CJ 토월극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>354</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>리사이틀홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>리사이틀홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>2527</seatcnt>
# <prfprocnt>2</prfprocnt>
# <totnmrs>3077</totnmrs>
# <prfnmplc>콘서트홀</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>예술의전당</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>241</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>301</totnmrs>
# <prfnmplc>자유소극장</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>예술의전당</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>600</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>IBK챔버홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>IBK챔버홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>2283</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>980</totnmrs>
# <prfnmplc>오페라극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>예술의전당</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>신세계스퀘어 야외무대</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>신세계스퀘어 야외무대</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>130</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>인춘아트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>인춘아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>1101어린이라운지</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>1101어린이라운지</prfnmfct>
# </prfst>]

# %% [markdown]
# ## 충무아트센터

# %%
start = "20180801"
last = "20180910"
start_date = datetime.strptime(start, "%Y%m%d")
last_date = datetime.strptime(last, "%Y%m%d")

# %%
#인증키 입력
encoding ='3618439972f548dd99831f9a6e4856e1' #발급받은 인코딩키 입력
# 종료일 까지 반복
while start_date <= last_date:
    string = str(start_date.year)
    if (start_date.month<10):
        string = string + str(0)
        string = string + str(start_date.month)
    else:
        string = string + str(start_date.month)
    if (start_date.day<10):
        string = string + str(0)
        string = string + str(start_date.day)
    else:
        string = string + str(start_date.day)
    print(string)
    #url 입력
    url = 'https://www.kopis.or.kr/openApi/restful/prfstsPrfByFct?'
    params ={'service' : encoding , 'cpage' : '1', 'rows' : '10', 'stdate' : string, 'eddate' : string,'sharea':'11','shprfnmfct':'충무아트센터' }

    response = requests.get(url, params=params)

    content = response.text

    xml_obj = bs4.BeautifulSoup(content,'lxml-xml')
    rows = xml_obj.findAll('prfst')
    print(rows)

    # xml 안의 데이터 수집
    for item in rows:
        seatcnt = item.find('seatcnt') #좌석 수
        seatcnt = seatcnt.get_text()
        totnmrs = item.find('totnmrs') #총 티켓 판매 수
        totnmrs = totnmrs.get_text()
        data = [seatcnt,totnmrs]
        datas.append(data)

    df = pd.DataFrame(datas, columns=['좌석 수', '티켓 판매수'])
    start_date += timedelta(days=1)
# Out:
# 20180801
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>대공연장</prfnmplc>
# <prfnmfct>대공연장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>195</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180802
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>대공연장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>대공연장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>189</totnmrs>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180803
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>대공연장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>대공연장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>236</totnmrs>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180804
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>대공연장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>대공연장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>254</totnmrs>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180805
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>대공연장</prfnmplc>
# <prfnmfct>대공연장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>282</totnmrs>
# <prfdtcnt>2</prfdtcnt>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180806
# []
# 20180807
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>31</totnmrs>
# <prfnmplc>대공연장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>중극장 블랙</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180808
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>38</totnmrs>
# <prfnmplc>대공연장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>중극장 블랙</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180809
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>5</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>대공연장</prfnmplc>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfnmfct>중극장 블랙</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180810
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>12</totnmrs>
# <prfnmplc>대공연장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>중극장 블랙</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180811
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>23</totnmrs>
# <prfnmplc>대공연장</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>311</totnmrs>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180812
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>57</totnmrs>
# <prfnmplc>대공연장</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>445</totnmrs>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180813
# []
# 20180814
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>53</totnmrs>
# <prfnmplc>대공연장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>156</totnmrs>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180815
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>54</totnmrs>
# <prfnmplc>대공연장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>424</totnmrs>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180816
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>28</totnmrs>
# <prfnmplc>대공연장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>142</totnmrs>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180817
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>54</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>대공연장</prfnmplc>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>189</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180818
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>88</totnmrs>
# <prfnmplc>대공연장</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>325</totnmrs>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180819
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>129</totnmrs>
# <prfnmplc>대공연장</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>434</totnmrs>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180820
# []
# 20180821
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>33</totnmrs>
# <prfnmplc>대공연장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>중극장 블랙</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180822
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>54</totnmrs>
# <prfnmplc>대공연장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>중극장 블랙</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180823
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>54</totnmrs>
# <prfnmplc>대공연장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>중극장 블랙</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180824
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>61</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>대공연장</prfnmplc>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfnmfct>중극장 블랙</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180825
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>114</totnmrs>
# <prfnmplc>대공연장</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>369</totnmrs>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180826
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>135</totnmrs>
# <prfnmplc>대공연장</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>395</totnmrs>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180827
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>대공연장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>대공연장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>178</totnmrs>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180828
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>34</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>대공연장</prfnmplc>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfnmfct>중극장 블랙</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180829
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>34</totnmrs>
# <prfnmplc>대공연장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>208</totnmrs>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180830
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>37</totnmrs>
# <prfnmplc>대공연장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>217</totnmrs>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180831
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>67</totnmrs>
# <prfnmplc>대공연장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>206</totnmrs>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180901
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>144</totnmrs>
# <prfdtcnt>2</prfdtcnt>
# <prfnmplc>대공연장</prfnmplc>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>404</totnmrs>
# <prfdtcnt>2</prfdtcnt>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180902
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>134</totnmrs>
# <prfnmplc>대공연장</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>460</totnmrs>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180903
# []
# 20180904
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>6</totnmrs>
# <prfnmplc>대공연장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>중극장 블랙</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180905
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>14</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>대공연장</prfnmplc>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfnmfct>중극장 블랙</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180906
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>20</totnmrs>
# <prfnmplc>대공연장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>중극장 블랙</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180907
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>25</totnmrs>
# <prfnmplc>대공연장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>중극장 블랙</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180908
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>52</totnmrs>
# <prfdtcnt>2</prfdtcnt>
# <prfnmplc>대공연장</prfnmplc>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>317</totnmrs>
# <prfdtcnt>2</prfdtcnt>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180909
# [<prfst>
# <seatcnt>218</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>소극장 블루</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>소극장 블루</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>55</totnmrs>
# <prfnmplc>대공연장</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>325</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>312</totnmrs>
# <prfnmplc>중극장 블랙</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>충무아트센터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨벤션센터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨벤션센터</prfnmfct>
# </prfst>]
# 20180910
# []

# %% [markdown]
# ## 세종문화회관

# %%
start = "20191001"
last = "20191110"
start_date = datetime.strptime(start, "%Y%m%d")
last_date = datetime.strptime(last, "%Y%m%d")

# %%
#인증키 입력
encoding ='3618439972f548dd99831f9a6e4856e1' #발급받은 인코딩키 입력
# 종료일 까지 반복
while start_date <= last_date:
    string = str(start_date.year)
    if (start_date.month<10):
        string = string + str(0)
        string = string + str(start_date.month)
    else:
        string = string + str(start_date.month)
    if (start_date.day<10):
        string = string + str(0)
        string = string + str(start_date.day)
    else:
        string = string + str(start_date.day)
    print(string)
    #url 입력
    url = 'https://www.kopis.or.kr/openApi/restful/prfstsPrfByFct?'
    params ={'service' : encoding , 'cpage' : '1', 'rows' : '10', 'stdate' : string, 'eddate' : string,'sharea':'11','shprfnmfct':'세종문화회관' }

    response = requests.get(url, params=params)

    content = response.text

    xml_obj = bs4.BeautifulSoup(content,'lxml-xml')
    rows = xml_obj.findAll('prfst')
    print(rows)

    # xml 안의 데이터 수집
    for item in rows:
        seatcnt = item.find('seatcnt') #좌석 수
        seatcnt = seatcnt.get_text()
        totnmrs = item.find('totnmrs') #총 티켓 판매 수
        totnmrs = totnmrs.get_text()
        data = [seatcnt,totnmrs]
        datas.append(data)

    df = pd.DataFrame(datas, columns=['좌석 수', '티켓 판매수'])
    start_date += timedelta(days=1)
# Out:
# 20191001
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>2981</totnmrs>
# <prfnmplc>세종대극장</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>438</totnmrs>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종M씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>117</totnmrs>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191002
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종대극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종대극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>438</totnmrs>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>602</totnmrs>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>126</totnmrs>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191003
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종대극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종대극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>436</totnmrs>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>552</totnmrs>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>154</totnmrs>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191004
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종대극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종대극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>438</totnmrs>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종M씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>105</totnmrs>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191005
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>1309</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>세종대극장</prfnmplc>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>360</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>602</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>181</totnmrs>
# <prfdtcnt>2</prfdtcnt>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191006
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종대극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종대극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>285</totnmrs>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>411</totnmrs>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>132</totnmrs>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191007
# []
# 20191008
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종대극장</prfnmplc>
# <prfnmfct>세종대극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>395</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfnmfct>세종M씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfnmfct>세종S씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191009
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종대극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종대극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>2</prfprocnt>
# <totnmrs>522</totnmrs>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종M씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종S씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191010
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종대극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종대극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>418</totnmrs>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>514</totnmrs>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종S씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191011
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종대극장</prfnmplc>
# <prfnmfct>세종대극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>422</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>519</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>216</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191012
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>6004</totnmrs>
# <prfnmplc>세종대극장</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종체임버홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>522</totnmrs>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종S씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191013
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>6004</totnmrs>
# <prfnmplc>세종대극장</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>298</totnmrs>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종M씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종S씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191014
# []
# 20191015
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>2295</totnmrs>
# <prfnmplc>세종대극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>366</totnmrs>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>91</totnmrs>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종S씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191016
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>2298</totnmrs>
# <prfnmplc>세종대극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>354</totnmrs>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>96</totnmrs>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>75</totnmrs>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191017
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종대극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종대극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>305</totnmrs>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종M씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>71</totnmrs>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191018
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종대극장</prfnmplc>
# <prfnmfct>세종대극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>427</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfnmfct>세종M씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfnmfct>세종S씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191019
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>1084</totnmrs>
# <prfnmplc>세종대극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>267</totnmrs>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>101</totnmrs>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>33</totnmrs>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191020
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종대극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종대극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>425</totnmrs>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>86</totnmrs>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>21</totnmrs>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191021
# []
# 20191022
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>2448</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>세종대극장</prfnmplc>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>421</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>602</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>298</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191023
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종대극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종대극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>286</totnmrs>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종M씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>90</totnmrs>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191024
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종대극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종대극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>436</totnmrs>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>558</totnmrs>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>90</totnmrs>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191025
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종대극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종대극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>299</totnmrs>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>583</totnmrs>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종S씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191026
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종대극장</prfnmplc>
# <prfnmfct>세종대극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>322</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>598</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>324</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191027
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종대극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종대극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>429</totnmrs>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종M씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>324</totnmrs>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191028
# []
# 20191029
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종대극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종대극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>87</totnmrs>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>236</totnmrs>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종S씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191030
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>1531</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>세종대극장</prfnmplc>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>122</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>602</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfnmfct>세종S씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191031
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>1485</totnmrs>
# <prfnmplc>세종대극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>121</totnmrs>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>601</totnmrs>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종S씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191101
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>1845</totnmrs>
# <prfnmplc>세종대극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>438</totnmrs>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종M씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>192</totnmrs>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191102
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>1515</totnmrs>
# <prfnmplc>세종대극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>374</totnmrs>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>602</totnmrs>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>218</totnmrs>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191103
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종대극장</prfnmplc>
# <prfnmfct>세종대극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>421</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>602</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>111</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191104
# []
# 20191105
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>1974</totnmrs>
# <prfnmplc>세종대극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>438</totnmrs>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>600</totnmrs>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>84</totnmrs>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191106
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종대극장</prfnmplc>
# <prfnmfct>세종대극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>435</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfnmfct>세종M씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>130</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191107
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>1424</totnmrs>
# <prfnmplc>세종대극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>403</totnmrs>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종M씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>108</totnmrs>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191108
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>3002</totnmrs>
# <prfnmplc>세종대극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>438</totnmrs>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종M씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>144</totnmrs>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191109
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종대극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종대극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>406</totnmrs>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종M씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>288</totnmrs>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]
# 20191110
# [<prfst>
# <seatcnt>3022</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>2682</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>세종대극장</prfnmplc>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>443</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>443</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>세종체임버홀</prfnmplc>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>609</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종M씨어터</prfnmplc>
# <prfnmfct>세종M씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>300</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>168</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>세종S씨어터</prfnmplc>
# <prfnmfct>세종문화회관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>뜨락(야외공간)(폐관)</prfnmplc>
# <prfnmfct>뜨락(야외공간)(폐관)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>94</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종예술아카데미(스퀘어홀)</prfnmplc>
# <prfnmfct>세종예술아카데미(스퀘어홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>50</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종예술아카데미(서클홀)</prfnmplc>
# <prfnmfct>세종예술아카데미(서클홀)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>세종예술아카데미(오픈스테이지)</prfnmplc>
# <prfnmfct>세종예술아카데미(오픈스테이지)</prfnmfct>
# </prfst>]

# %% [markdown]
# ## 예스24 스테이지

# %%
start = "20170101"
last = "20170201"
start_date = datetime.strptime(start, "%Y%m%d")
last_date = datetime.strptime(last, "%Y%m%d")

# %%
#인증키 입력
encoding ='3618439972f548dd99831f9a6e4856e1' #발급받은 인코딩키 입력
# 종료일 까지 반복
while start_date <= last_date:
    string = str(start_date.year)
    if (start_date.month<10):
        string = string + str(0)
        string = string + str(start_date.month)
    else:
        string = string + str(start_date.month)
    if (start_date.day<10):
        string = string + str(0)
        string = string + str(start_date.day)
    else:
        string = string + str(start_date.day)
    print(string)
    #url 입력
    url = 'https://www.kopis.or.kr/openApi/restful/prfstsPrfByFct?'
    params ={'service' : encoding , 'cpage' : '1', 'rows' : '10', 'stdate' : string, 'eddate' : string,'sharea':'11','shprfnmfct':'예스 24 스테이지(구. DCF 대명문화공장)' }

    response = requests.get(url, params=params)

    content = response.text

    xml_obj = bs4.BeautifulSoup(content,'lxml-xml')
    rows = xml_obj.findAll('prfst')
    print(rows)

    # xml 안의 데이터 수집
    for item in rows:
        seatcnt = item.find('seatcnt') #좌석 수
        seatcnt = seatcnt.get_text()
        totnmrs = item.find('totnmrs') #총 티켓 판매 수
        totnmrs = totnmrs.get_text()
        data = [seatcnt,totnmrs]
        datas.append(data)

    df = pd.DataFrame(datas, columns=['좌석 수', '티켓 판매수'])
    start_date += timedelta(days=1)
# Out:
# 20170101
# [<prfst>
# <seatcnt>406</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>1관</prfnmplc>
# <prfnmfct>1관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>301</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>2관</prfnmplc>
# <prfnmfct>2관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>3관(구. 수현재씨어터)</prfnmplc>
# <prfnmfct>3관(구. 수현재씨어터)</prfnmfct>
# </prfst>]
# 20170102
# []
# 20170103
# [<prfst>
# <seatcnt>406</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>1관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>301</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>2관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관(구. 수현재씨어터)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관(구. 수현재씨어터)</prfnmfct>
# </prfst>]
# 20170104
# [<prfst>
# <seatcnt>406</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>1관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>301</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>2관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관(구. 수현재씨어터)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관(구. 수현재씨어터)</prfnmfct>
# </prfst>]
# 20170105
# [<prfst>
# <seatcnt>406</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>1관</prfnmplc>
# <prfnmfct>1관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>301</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>2관</prfnmplc>
# <prfnmfct>2관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>3관(구. 수현재씨어터)</prfnmplc>
# <prfnmfct>3관(구. 수현재씨어터)</prfnmfct>
# </prfst>]
# 20170106
# [<prfst>
# <seatcnt>406</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>1관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>301</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>2관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관(구. 수현재씨어터)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관(구. 수현재씨어터)</prfnmfct>
# </prfst>]
# 20170107
# [<prfst>
# <seatcnt>406</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>1관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>301</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>2관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관(구. 수현재씨어터)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관(구. 수현재씨어터)</prfnmfct>
# </prfst>]
# 20170108
# [<prfst>
# <seatcnt>406</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>1관</prfnmplc>
# <prfnmfct>1관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>301</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>2관</prfnmplc>
# <prfnmfct>2관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>3관(구. 수현재씨어터)</prfnmplc>
# <prfnmfct>3관(구. 수현재씨어터)</prfnmfct>
# </prfst>]
# 20170109
# []
# 20170110
# [<prfst>
# <seatcnt>406</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>1관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>301</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>2관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관(구. 수현재씨어터)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관(구. 수현재씨어터)</prfnmfct>
# </prfst>]
# 20170111
# [<prfst>
# <seatcnt>406</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>1관</prfnmplc>
# <prfnmfct>1관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>301</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>2관</prfnmplc>
# <prfnmfct>2관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>3관(구. 수현재씨어터)</prfnmplc>
# <prfnmfct>3관(구. 수현재씨어터)</prfnmfct>
# </prfst>]
# 20170112
# [<prfst>
# <seatcnt>406</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>1관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>301</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>2관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관(구. 수현재씨어터)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관(구. 수현재씨어터)</prfnmfct>
# </prfst>]
# 20170113
# [<prfst>
# <seatcnt>406</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>1관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>301</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>2관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관(구. 수현재씨어터)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관(구. 수현재씨어터)</prfnmfct>
# </prfst>]
# 20170114
# [<prfst>
# <seatcnt>406</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>1관</prfnmplc>
# <prfnmfct>1관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>301</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>2관</prfnmplc>
# <prfnmfct>2관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>3관(구. 수현재씨어터)</prfnmplc>
# <prfnmfct>3관(구. 수현재씨어터)</prfnmfct>
# </prfst>]
# 20170115
# [<prfst>
# <seatcnt>406</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>1관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>301</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>2관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관(구. 수현재씨어터)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관(구. 수현재씨어터)</prfnmfct>
# </prfst>]
# 20170116
# []
# 20170117
# [<prfst>
# <seatcnt>406</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>1관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>301</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>2관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관(구. 수현재씨어터)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관(구. 수현재씨어터)</prfnmfct>
# </prfst>]
# 20170118
# [<prfst>
# <seatcnt>406</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>1관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>301</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>2관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관(구. 수현재씨어터)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관(구. 수현재씨어터)</prfnmfct>
# </prfst>]
# 20170119
# [<prfst>
# <seatcnt>406</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>1관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>301</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>2관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관(구. 수현재씨어터)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관(구. 수현재씨어터)</prfnmfct>
# </prfst>]
# 20170120
# [<prfst>
# <seatcnt>406</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>1관</prfnmplc>
# <prfnmfct>1관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>301</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>2관</prfnmplc>
# <prfnmfct>2관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>3관(구. 수현재씨어터)</prfnmplc>
# <prfnmfct>3관(구. 수현재씨어터)</prfnmfct>
# </prfst>]
# 20170121
# [<prfst>
# <seatcnt>406</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>1관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>301</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>2관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관(구. 수현재씨어터)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관(구. 수현재씨어터)</prfnmfct>
# </prfst>]
# 20170122
# [<prfst>
# <seatcnt>406</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>1관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>301</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>2관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관(구. 수현재씨어터)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관(구. 수현재씨어터)</prfnmfct>
# </prfst>]
# 20170123
# []
# 20170124
# [<prfst>
# <seatcnt>406</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>1관</prfnmplc>
# <prfnmfct>1관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>301</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>2관</prfnmplc>
# <prfnmfct>2관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>3관(구. 수현재씨어터)</prfnmplc>
# <prfnmfct>3관(구. 수현재씨어터)</prfnmfct>
# </prfst>]
# 20170125
# [<prfst>
# <seatcnt>406</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>1관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>301</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>2관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관(구. 수현재씨어터)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관(구. 수현재씨어터)</prfnmfct>
# </prfst>]
# 20170126
# [<prfst>
# <seatcnt>406</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>1관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>301</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>2관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관(구. 수현재씨어터)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관(구. 수현재씨어터)</prfnmfct>
# </prfst>]
# 20170127
# [<prfst>
# <seatcnt>406</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>1관</prfnmplc>
# <prfnmfct>1관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>301</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>2관</prfnmplc>
# <prfnmfct>2관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>3관(구. 수현재씨어터)</prfnmplc>
# <prfnmfct>3관(구. 수현재씨어터)</prfnmfct>
# </prfst>]
# 20170128
# [<prfst>
# <seatcnt>406</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>1관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>301</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>2관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관(구. 수현재씨어터)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관(구. 수현재씨어터)</prfnmfct>
# </prfst>]
# 20170129
# [<prfst>
# <seatcnt>406</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>1관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>301</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>2관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관(구. 수현재씨어터)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관(구. 수현재씨어터)</prfnmfct>
# </prfst>]
# 20170130
# [<prfst>
# <seatcnt>406</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>1관</prfnmplc>
# <prfnmfct>1관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>301</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>2관</prfnmplc>
# <prfnmfct>2관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>3관(구. 수현재씨어터)</prfnmplc>
# <prfnmfct>3관(구. 수현재씨어터)</prfnmfct>
# </prfst>]
# 20170131
# [<prfst>
# <seatcnt>406</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>1관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>301</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>2관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관(구. 수현재씨어터)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관(구. 수현재씨어터)</prfnmfct>
# </prfst>]
# 20170201
# [<prfst>
# <seatcnt>406</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>1관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>301</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>2관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>255</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관(구. 수현재씨어터)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관(구. 수현재씨어터)</prfnmfct>
# </prfst>]

# %% [markdown]
# ## 코엑스

# %%
start = "20211210"
last = "20220115"
start_date = datetime.strptime(start, "%Y%m%d")
last_date = datetime.strptime(last, "%Y%m%d")

# %%
#인증키 입력
encoding ='3618439972f548dd99831f9a6e4856e1' #발급받은 인코딩키 입력
# 종료일 까지 반복
while start_date <= last_date:
    string = str(start_date.year)
    if (start_date.month<10):
        string = string + str(0)
        string = string + str(start_date.month)
    else:
        string = string + str(start_date.month)
    if (start_date.day<10):
        string = string + str(0)
        string = string + str(start_date.day)
    else:
        string = string + str(start_date.day)
    print(string)
    #url 입력
    url = 'https://www.kopis.or.kr/openApi/restful/prfstsPrfByFct?'
    params ={'service' : encoding , 'cpage' : '1', 'rows' : '10', 'stdate' : string, 'eddate' : string,'sharea':'11','shprfnmfct':'코엑스' }

    response = requests.get(url, params=params)

    content = response.text

    xml_obj = bs4.BeautifulSoup(content,'lxml-xml')
    rows = xml_obj.findAll('prfst')
    print(rows)

    # xml 안의 데이터 수집
    for item in rows:
        seatcnt = item.find('seatcnt') #좌석 수
        seatcnt = seatcnt.get_text()
        totnmrs = item.find('totnmrs') #총 티켓 판매 수
        totnmrs = totnmrs.get_text()
        data = [seatcnt,totnmrs]
        datas.append(data)

    df = pd.DataFrame(datas, columns=['좌석 수', '티켓 판매수'])
    start_date += timedelta(days=1)
# Out:
# 20211210
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>353</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>코엑스 신한카드 아티움</prfnmplc>
# <prfnmfct>코엑스</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>아트홀</prfnmplc>
# <prfnmfct>아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1080</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>오디토리움</prfnmplc>
# <prfnmfct>오디토리움</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>450</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>컨퍼런스룸(남)</prfnmplc>
# <prfnmfct>컨퍼런스룸(남)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>K팝 광장(동문)</prfnmplc>
# <prfnmfct>K팝 광장(동문)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>7000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>D홀</prfnmplc>
# <prfnmfct>D홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1800</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>그랜드볼룸</prfnmplc>
# <prfnmfct>그랜드볼룸</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>Hall C</prfnmplc>
# <prfnmfct>Hall C</prfnmfct>
# </prfst>]
# 20211211
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>724</totnmrs>
# <prfnmplc>코엑스 신한카드 아티움</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>코엑스</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>아트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1080</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>오디토리움</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>오디토리움</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>450</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨퍼런스룸(남)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨퍼런스룸(남)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>K팝 광장(동문)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>K팝 광장(동문)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>7000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>D홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>D홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1800</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>그랜드볼룸</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>그랜드볼룸</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>Hall C</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>Hall C</prfnmfct>
# </prfst>]
# 20211212
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>844</totnmrs>
# <prfnmplc>코엑스 신한카드 아티움</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>코엑스</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>아트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1080</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>오디토리움</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>오디토리움</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>450</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨퍼런스룸(남)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨퍼런스룸(남)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>K팝 광장(동문)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>K팝 광장(동문)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>7000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>D홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>D홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1800</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>그랜드볼룸</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>그랜드볼룸</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>Hall C</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>Hall C</prfnmfct>
# </prfst>]
# 20211213
# []
# 20211214
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>252</totnmrs>
# <prfnmplc>코엑스 신한카드 아티움</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>코엑스</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>아트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1080</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>오디토리움</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>오디토리움</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>450</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨퍼런스룸(남)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨퍼런스룸(남)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>K팝 광장(동문)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>K팝 광장(동문)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>7000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>D홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>D홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1800</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>그랜드볼룸</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>그랜드볼룸</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>Hall C</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>Hall C</prfnmfct>
# </prfst>]
# 20211215
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>490</totnmrs>
# <prfnmplc>코엑스 신한카드 아티움</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>코엑스</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>아트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1080</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>오디토리움</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>오디토리움</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>450</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨퍼런스룸(남)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨퍼런스룸(남)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>K팝 광장(동문)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>K팝 광장(동문)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>7000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>D홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>D홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1800</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>그랜드볼룸</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>그랜드볼룸</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>Hall C</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>Hall C</prfnmfct>
# </prfst>]
# 20211216
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>256</totnmrs>
# <prfnmplc>코엑스 신한카드 아티움</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>코엑스</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>아트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1080</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>오디토리움</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>오디토리움</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>450</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨퍼런스룸(남)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨퍼런스룸(남)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>K팝 광장(동문)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>K팝 광장(동문)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>7000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>D홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>D홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1800</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>그랜드볼룸</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>그랜드볼룸</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>Hall C</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>Hall C</prfnmfct>
# </prfst>]
# 20211217
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>368</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>코엑스 신한카드 아티움</prfnmplc>
# <prfnmfct>코엑스</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>아트홀</prfnmplc>
# <prfnmfct>아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1080</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>오디토리움</prfnmplc>
# <prfnmfct>오디토리움</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>450</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>컨퍼런스룸(남)</prfnmplc>
# <prfnmfct>컨퍼런스룸(남)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>K팝 광장(동문)</prfnmplc>
# <prfnmfct>K팝 광장(동문)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>7000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>D홀</prfnmplc>
# <prfnmfct>D홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1800</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>그랜드볼룸</prfnmplc>
# <prfnmfct>그랜드볼룸</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>Hall C</prfnmplc>
# <prfnmfct>Hall C</prfnmfct>
# </prfst>]
# 20211218
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>757</totnmrs>
# <prfnmplc>코엑스 신한카드 아티움</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>코엑스</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>아트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1080</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>오디토리움</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>오디토리움</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>450</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨퍼런스룸(남)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨퍼런스룸(남)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>K팝 광장(동문)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>K팝 광장(동문)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>7000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>D홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>D홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1800</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>그랜드볼룸</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>그랜드볼룸</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>Hall C</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>Hall C</prfnmfct>
# </prfst>]
# 20211219
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>705</totnmrs>
# <prfnmplc>코엑스 신한카드 아티움</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>코엑스</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>아트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1080</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>오디토리움</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>오디토리움</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>450</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨퍼런스룸(남)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨퍼런스룸(남)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>K팝 광장(동문)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>K팝 광장(동문)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>7000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>D홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>D홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1800</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>그랜드볼룸</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>그랜드볼룸</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>Hall C</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>Hall C</prfnmfct>
# </prfst>]
# 20211220
# []
# 20211221
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>231</totnmrs>
# <prfdtcnt>2</prfdtcnt>
# <prfnmplc>코엑스 신한카드 아티움</prfnmplc>
# <prfnmfct>코엑스</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>아트홀</prfnmplc>
# <prfnmfct>아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1080</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>오디토리움</prfnmplc>
# <prfnmfct>오디토리움</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>450</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>컨퍼런스룸(남)</prfnmplc>
# <prfnmfct>컨퍼런스룸(남)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>K팝 광장(동문)</prfnmplc>
# <prfnmfct>K팝 광장(동문)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>7000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>D홀</prfnmplc>
# <prfnmfct>D홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1800</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>그랜드볼룸</prfnmplc>
# <prfnmfct>그랜드볼룸</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>Hall C</prfnmplc>
# <prfnmfct>Hall C</prfnmfct>
# </prfst>]
# 20211222
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>349</totnmrs>
# <prfnmplc>코엑스 신한카드 아티움</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>코엑스</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>아트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1080</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>오디토리움</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>오디토리움</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>450</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨퍼런스룸(남)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨퍼런스룸(남)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>K팝 광장(동문)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>K팝 광장(동문)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>7000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>D홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>D홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1800</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>그랜드볼룸</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>그랜드볼룸</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>Hall C</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>Hall C</prfnmfct>
# </prfst>]
# 20211223
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>208</totnmrs>
# <prfnmplc>코엑스 신한카드 아티움</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>코엑스</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>아트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1080</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>오디토리움</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>오디토리움</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>450</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨퍼런스룸(남)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨퍼런스룸(남)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>K팝 광장(동문)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>K팝 광장(동문)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>7000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>D홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>D홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1800</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>그랜드볼룸</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>그랜드볼룸</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>Hall C</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>Hall C</prfnmfct>
# </prfst>]
# 20211224
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>537</totnmrs>
# <prfnmplc>코엑스 신한카드 아티움</prfnmplc>
# <prfdtcnt>4</prfdtcnt>
# <prfnmfct>코엑스</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>아트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1080</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>오디토리움</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>오디토리움</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>450</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨퍼런스룸(남)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨퍼런스룸(남)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>K팝 광장(동문)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>K팝 광장(동문)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>7000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>D홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>D홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1800</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>그랜드볼룸</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>그랜드볼룸</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>Hall C</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>Hall C</prfnmfct>
# </prfst>]
# 20211225
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>1010</totnmrs>
# <prfnmplc>코엑스 신한카드 아티움</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>코엑스</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>아트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1080</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>오디토리움</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>오디토리움</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>450</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨퍼런스룸(남)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨퍼런스룸(남)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>K팝 광장(동문)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>K팝 광장(동문)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>7000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>D홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>D홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1800</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>그랜드볼룸</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>그랜드볼룸</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>Hall C</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>Hall C</prfnmfct>
# </prfst>]
# 20211226
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>865</totnmrs>
# <prfnmplc>코엑스 신한카드 아티움</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>코엑스</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>아트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1080</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>오디토리움</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>오디토리움</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>450</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨퍼런스룸(남)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨퍼런스룸(남)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>K팝 광장(동문)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>K팝 광장(동문)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>7000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>D홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>D홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1800</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>그랜드볼룸</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>그랜드볼룸</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>Hall C</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>Hall C</prfnmfct>
# </prfst>]
# 20211227
# []
# 20211228
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>271</totnmrs>
# <prfnmplc>코엑스 신한카드 아티움</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>코엑스</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>아트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1080</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>오디토리움</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>오디토리움</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>450</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨퍼런스룸(남)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨퍼런스룸(남)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>K팝 광장(동문)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>K팝 광장(동문)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>7000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>D홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>D홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1800</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>그랜드볼룸</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>그랜드볼룸</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>Hall C</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>Hall C</prfnmfct>
# </prfst>]
# 20211229
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>706</totnmrs>
# <prfnmplc>코엑스 신한카드 아티움</prfnmplc>
# <prfdtcnt>4</prfdtcnt>
# <prfnmfct>코엑스</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>아트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1080</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>오디토리움</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>오디토리움</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>450</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨퍼런스룸(남)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨퍼런스룸(남)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>K팝 광장(동문)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>K팝 광장(동문)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>7000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>D홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>D홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1800</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>그랜드볼룸</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>그랜드볼룸</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>Hall C</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>Hall C</prfnmfct>
# </prfst>]
# 20211230
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>403</totnmrs>
# <prfdtcnt>2</prfdtcnt>
# <prfnmplc>코엑스 신한카드 아티움</prfnmplc>
# <prfnmfct>코엑스</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>아트홀</prfnmplc>
# <prfnmfct>아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1080</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>오디토리움</prfnmplc>
# <prfnmfct>오디토리움</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>450</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>컨퍼런스룸(남)</prfnmplc>
# <prfnmfct>컨퍼런스룸(남)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>K팝 광장(동문)</prfnmplc>
# <prfnmfct>K팝 광장(동문)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>7000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>D홀</prfnmplc>
# <prfnmfct>D홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1800</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>그랜드볼룸</prfnmplc>
# <prfnmfct>그랜드볼룸</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>Hall C</prfnmplc>
# <prfnmfct>Hall C</prfnmfct>
# </prfst>]
# 20211231
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>291</totnmrs>
# <prfnmplc>코엑스 신한카드 아티움</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>코엑스</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>아트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1080</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>오디토리움</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>오디토리움</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>450</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨퍼런스룸(남)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨퍼런스룸(남)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>K팝 광장(동문)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>K팝 광장(동문)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>7000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>D홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>D홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1800</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>그랜드볼룸</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>그랜드볼룸</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>Hall C</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>Hall C</prfnmfct>
# </prfst>]
# 20220101
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>593</totnmrs>
# <prfnmplc>코엑스 신한카드 아티움</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>코엑스</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>아트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1080</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>오디토리움</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>오디토리움</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>450</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨퍼런스룸(남)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨퍼런스룸(남)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>K팝 광장(동문)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>K팝 광장(동문)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>7000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>D홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>D홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1800</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>그랜드볼룸</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>그랜드볼룸</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>Hall C</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>Hall C</prfnmfct>
# </prfst>]
# 20220102
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>826</totnmrs>
# <prfdtcnt>2</prfdtcnt>
# <prfnmplc>코엑스 신한카드 아티움</prfnmplc>
# <prfnmfct>코엑스</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>아트홀</prfnmplc>
# <prfnmfct>아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1080</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>오디토리움</prfnmplc>
# <prfnmfct>오디토리움</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>450</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>컨퍼런스룸(남)</prfnmplc>
# <prfnmfct>컨퍼런스룸(남)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>K팝 광장(동문)</prfnmplc>
# <prfnmfct>K팝 광장(동문)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>7000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>D홀</prfnmplc>
# <prfnmfct>D홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1800</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>그랜드볼룸</prfnmplc>
# <prfnmfct>그랜드볼룸</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>Hall C</prfnmplc>
# <prfnmfct>Hall C</prfnmfct>
# </prfst>]
# 20220103
# []
# 20220104
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>209</totnmrs>
# <prfnmplc>코엑스 신한카드 아티움</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>코엑스</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>아트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1080</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>오디토리움</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>오디토리움</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>450</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨퍼런스룸(남)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨퍼런스룸(남)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>K팝 광장(동문)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>K팝 광장(동문)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>7000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>D홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>D홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1800</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>그랜드볼룸</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>그랜드볼룸</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>Hall C</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>Hall C</prfnmfct>
# </prfst>]
# 20220105
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>489</totnmrs>
# <prfnmplc>코엑스 신한카드 아티움</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>코엑스</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>아트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1080</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>오디토리움</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>오디토리움</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>450</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨퍼런스룸(남)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨퍼런스룸(남)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>K팝 광장(동문)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>K팝 광장(동문)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>7000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>D홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>D홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1800</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>그랜드볼룸</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>그랜드볼룸</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>Hall C</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>Hall C</prfnmfct>
# </prfst>]
# 20220106
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>213</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>코엑스 신한카드 아티움</prfnmplc>
# <prfnmfct>코엑스</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>아트홀</prfnmplc>
# <prfnmfct>아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1080</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>오디토리움</prfnmplc>
# <prfnmfct>오디토리움</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>450</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>컨퍼런스룸(남)</prfnmplc>
# <prfnmfct>컨퍼런스룸(남)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>K팝 광장(동문)</prfnmplc>
# <prfnmfct>K팝 광장(동문)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>7000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>D홀</prfnmplc>
# <prfnmfct>D홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1800</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>그랜드볼룸</prfnmplc>
# <prfnmfct>그랜드볼룸</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>Hall C</prfnmplc>
# <prfnmfct>Hall C</prfnmfct>
# </prfst>]
# 20220107
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>294</totnmrs>
# <prfnmplc>코엑스 신한카드 아티움</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>코엑스</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>아트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1080</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>오디토리움</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>오디토리움</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>450</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨퍼런스룸(남)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨퍼런스룸(남)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>K팝 광장(동문)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>K팝 광장(동문)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>7000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>D홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>D홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1800</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>그랜드볼룸</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>그랜드볼룸</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>Hall C</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>Hall C</prfnmfct>
# </prfst>]
# 20220108
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>671</totnmrs>
# <prfnmplc>코엑스 신한카드 아티움</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>코엑스</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>아트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1080</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>오디토리움</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>오디토리움</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>450</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨퍼런스룸(남)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨퍼런스룸(남)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>K팝 광장(동문)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>K팝 광장(동문)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>7000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>D홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>D홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1800</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>그랜드볼룸</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>그랜드볼룸</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>Hall C</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>Hall C</prfnmfct>
# </prfst>]
# 20220109
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>614</totnmrs>
# <prfnmplc>코엑스 신한카드 아티움</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>코엑스</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>아트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1080</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>오디토리움</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>오디토리움</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>450</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨퍼런스룸(남)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨퍼런스룸(남)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>K팝 광장(동문)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>K팝 광장(동문)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>7000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>D홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>D홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1800</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>그랜드볼룸</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>그랜드볼룸</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>Hall C</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>Hall C</prfnmfct>
# </prfst>]
# 20220110
# []
# 20220111
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>207</totnmrs>
# <prfnmplc>코엑스 신한카드 아티움</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>코엑스</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>아트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1080</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>오디토리움</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>오디토리움</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>450</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨퍼런스룸(남)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨퍼런스룸(남)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>K팝 광장(동문)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>K팝 광장(동문)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>7000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>D홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>D홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1800</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>그랜드볼룸</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>그랜드볼룸</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>Hall C</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>Hall C</prfnmfct>
# </prfst>]
# 20220112
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>489</totnmrs>
# <prfnmplc>코엑스 신한카드 아티움</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>코엑스</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>아트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1080</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>오디토리움</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>오디토리움</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>450</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨퍼런스룸(남)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨퍼런스룸(남)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>K팝 광장(동문)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>K팝 광장(동문)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>7000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>D홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>D홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1800</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>그랜드볼룸</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>그랜드볼룸</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>Hall C</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>Hall C</prfnmfct>
# </prfst>]
# 20220113
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>215</totnmrs>
# <prfnmplc>코엑스 신한카드 아티움</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>코엑스</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>아트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1080</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>오디토리움</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>오디토리움</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>450</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨퍼런스룸(남)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨퍼런스룸(남)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>K팝 광장(동문)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>K팝 광장(동문)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>7000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>D홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>D홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1800</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>그랜드볼룸</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>그랜드볼룸</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>Hall C</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>Hall C</prfnmfct>
# </prfst>]
# 20220114
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>286</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>코엑스 신한카드 아티움</prfnmplc>
# <prfnmfct>코엑스</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>아트홀</prfnmplc>
# <prfnmfct>아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1080</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>오디토리움</prfnmplc>
# <prfnmfct>오디토리움</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>450</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>컨퍼런스룸(남)</prfnmplc>
# <prfnmfct>컨퍼런스룸(남)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>K팝 광장(동문)</prfnmplc>
# <prfnmfct>K팝 광장(동문)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>7000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>D홀</prfnmplc>
# <prfnmfct>D홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1800</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>그랜드볼룸</prfnmplc>
# <prfnmfct>그랜드볼룸</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>Hall C</prfnmplc>
# <prfnmfct>Hall C</prfnmfct>
# </prfst>]
# 20220115
# [<prfst>
# <seatcnt>1004</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>850</totnmrs>
# <prfnmplc>코엑스 신한카드 아티움</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>코엑스</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>200</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>아트홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>아트홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1080</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>오디토리움</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>오디토리움</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>450</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>컨퍼런스룸(남)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>컨퍼런스룸(남)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>K팝 광장(동문)</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>K팝 광장(동문)</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>7000</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>D홀</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>D홀</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1800</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>그랜드볼룸</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>그랜드볼룸</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>0</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>Hall C</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>Hall C</prfnmfct>
# </prfst>]

# %% [markdown]
# ## 아트원씨어터(대학로)

# %%
start = "20180306"
last = "20180415"
start_date = datetime.strptime(start, "%Y%m%d")
last_date = datetime.strptime(last, "%Y%m%d")

# %%
#인증키 입력
encoding ='3618439972f548dd99831f9a6e4856e1' #발급받은 인코딩키 입력
# 종료일 까지 반복
while start_date <= last_date:
    string = str(start_date.year)
    if (start_date.month<10):
        string = string + str(0)
        string = string + str(start_date.month)
    else:
        string = string + str(start_date.month)
    if (start_date.day<10):
        string = string + str(0)
        string = string + str(start_date.day)
    else:
        string = string + str(start_date.day)
    print(string)
    #url 입력
    url = 'https://www.kopis.or.kr/openApi/restful/prfstsPrfByFct?'
    params ={'service' : encoding , 'cpage' : '1', 'rows' : '10', 'stdate' : string, 'eddate' : string,'sharea':'11','shprfnmfct':'대학로아트원씨어터' }

    response = requests.get(url, params=params)

    content = response.text

    xml_obj = bs4.BeautifulSoup(content,'lxml-xml')
    rows = xml_obj.findAll('prfst')
    print(rows)

    # xml 안의 데이터 수집
    for item in rows:
        seatcnt = item.find('seatcnt') #좌석 수
        seatcnt = seatcnt.get_text()
        totnmrs = item.find('totnmrs') #총 티켓 판매 수
        totnmrs = totnmrs.get_text()
        data = [seatcnt,totnmrs]
        datas.append(data)

    df = pd.DataFrame(datas, columns=['좌석 수', '티켓 판매수'])
    start_date += timedelta(days=1)
# Out:
# 20180311
# [<prfst>
# <seatcnt>365</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>1관</prfnmplc>
# <prfnmfct>1관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>250</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>3</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>2관</prfnmplc>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>158</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>3관</prfnmplc>
# <prfnmfct>3관</prfnmfct>
# </prfst>]
# 20180312
# []
# 20180313
# []
# 20180314
# []
# 20180315
# []
# 20180316
# []
# 20180317
# []
# 20180318
# []
# 20180319
# []
# 20180320
# []
# 20180321
# []
# 20180322
# [<prfst>
# <seatcnt>365</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>1관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>250</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>1</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>158</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관</prfnmfct>
# </prfst>]
# 20180323
# [<prfst>
# <seatcnt>365</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>60</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>250</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>19</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>158</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관</prfnmfct>
# </prfst>]
# 20180324
# [<prfst>
# <seatcnt>365</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>163</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>250</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>39</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>158</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관</prfnmfct>
# </prfst>]
# 20180325
# [<prfst>
# <seatcnt>365</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>91</totnmrs>
# <prfdtcnt>2</prfdtcnt>
# <prfnmplc>1관</prfnmplc>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>250</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>17</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>2관</prfnmplc>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>158</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>3관</prfnmplc>
# <prfnmfct>3관</prfnmfct>
# </prfst>]
# 20180326
# []
# 20180327
# [<prfst>
# <seatcnt>365</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>27</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>250</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>20</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>158</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관</prfnmfct>
# </prfst>]
# 20180328
# [<prfst>
# <seatcnt>365</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>172</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>250</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>20</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>158</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관</prfnmfct>
# </prfst>]
# 20180329
# [<prfst>
# <seatcnt>365</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>15</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>1관</prfnmplc>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>250</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>20</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>2관</prfnmplc>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>158</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>3관</prfnmplc>
# <prfnmfct>3관</prfnmfct>
# </prfst>]
# 20180330
# [<prfst>
# <seatcnt>365</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>63</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>250</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>20</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>158</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관</prfnmfct>
# </prfst>]
# 20180331
# [<prfst>
# <seatcnt>365</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>126</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>250</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>49</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>158</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관</prfnmfct>
# </prfst>]
# 20180401
# [<prfst>
# <seatcnt>365</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>129</totnmrs>
# <prfdtcnt>2</prfdtcnt>
# <prfnmplc>1관</prfnmplc>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>250</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>19</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>2관</prfnmplc>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>158</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>3관</prfnmplc>
# <prfnmfct>3관</prfnmfct>
# </prfst>]
# 20180402
# []
# 20180403
# [<prfst>
# <seatcnt>365</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>66</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>250</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>18</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>158</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관</prfnmfct>
# </prfst>]
# 20180404
# [<prfst>
# <seatcnt>365</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>112</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>250</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>20</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>158</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관</prfnmfct>
# </prfst>]
# 20180405
# [<prfst>
# <seatcnt>365</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>59</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>250</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>20</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>158</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관</prfnmfct>
# </prfst>]
# 20180406
# [<prfst>
# <seatcnt>365</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>37</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>250</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>23</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>158</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관</prfnmfct>
# </prfst>]
# 20180407
# [<prfst>
# <seatcnt>365</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>140</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>250</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>41</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>158</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관</prfnmfct>
# </prfst>]
# 20180408
# [<prfst>
# <seatcnt>365</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>163</totnmrs>
# <prfdtcnt>2</prfdtcnt>
# <prfnmplc>1관</prfnmplc>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>250</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>21</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>2관</prfnmplc>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>158</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>3관</prfnmplc>
# <prfnmfct>3관</prfnmfct>
# </prfst>]
# 20180409
# []
# 20180410
# [<prfst>
# <seatcnt>365</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>74</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>250</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>21</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>158</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관</prfnmfct>
# </prfst>]
# 20180411
# [<prfst>
# <seatcnt>365</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>54</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>250</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>23</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>158</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관</prfnmfct>
# </prfst>]
# 20180412
# [<prfst>
# <seatcnt>365</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>66</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>1관</prfnmplc>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>250</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>21</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>2관</prfnmplc>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>158</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>3관</prfnmplc>
# <prfnmfct>3관</prfnmfct>
# </prfst>]
# 20180413
# [<prfst>
# <seatcnt>365</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>30</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>250</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>20</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>158</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관</prfnmfct>
# </prfst>]
# 20180414
# [<prfst>
# <seatcnt>365</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>179</totnmrs>
# <prfdtcnt>2</prfdtcnt>
# <prfnmplc>1관</prfnmplc>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>250</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>23</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>2관</prfnmplc>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>158</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>3관</prfnmplc>
# <prfnmfct>3관</prfnmfct>
# </prfst>]
# 20180415
# [<prfst>
# <seatcnt>365</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>173</totnmrs>
# <prfnmplc>1관</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>대학로아트원씨어터</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>250</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>2관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>2관</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>158</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>3관</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>3관</prfnmfct>
# </prfst>]

# %% [markdown]
# ## 아르코 예술극장

# %%
start = "20180401"
last = "20180501"
start_date = datetime.strptime(start, "%Y%m%d")
last_date = datetime.strptime(last, "%Y%m%d")

# %%
#인증키 입력
encoding ='3618439972f548dd99831f9a6e4856e1' #발급받은 인코딩키 입력
# 종료일 까지 반복
while start_date <= last_date:
    string = str(start_date.year)
    if (start_date.month<10):
        string = string + str(0)
        string = string + str(start_date.month)
    else:
        string = string + str(start_date.month)
    if (start_date.day<10):
        string = string + str(0)
        string = string + str(start_date.day)
    else:
        string = string + str(start_date.day)
    print(string)
    #url 입력
    url = 'https://www.kopis.or.kr/openApi/restful/prfstsPrfByFct?'
    params ={'service' : encoding , 'cpage' : '1', 'rows' : '10', 'stdate' : string, 'eddate' : string,'sharea':'11','shprfnmfct':'아르코예술극장' }

    response = requests.get(url, params=params)

    content = response.text

    xml_obj = bs4.BeautifulSoup(content,'lxml-xml')
    rows = xml_obj.findAll('prfst')
    print(rows)

    # xml 안의 데이터 수집
    for item in rows:
        seatcnt = item.find('seatcnt') #좌석 수
        seatcnt = seatcnt.get_text()
        totnmrs = item.find('totnmrs') #총 티켓 판매 수
        totnmrs = totnmrs.get_text()
        data = [seatcnt,totnmrs]
        datas.append(data)

    df = pd.DataFrame(datas, columns=['좌석 수', '티켓 판매수'])
    start_date += timedelta(days=1)
# Out:
# 20180401
# [<prfst>
# <seatcnt>600</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>대극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>대극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>110</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>245</totnmrs>
# <prfnmplc>소극장</prfnmplc>
# <prfdtcnt>7</prfdtcnt>
# <prfnmfct>아르코예술극장</prfnmfct>
# </prfst>]
# 20180402
# []
# 20180403
# [<prfst>
# <seatcnt>600</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>67</totnmrs>
# <prfnmplc>대극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>아르코예술극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>110</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>223</totnmrs>
# <prfnmplc>소극장</prfnmplc>
# <prfdtcnt>7</prfdtcnt>
# <prfnmfct>아르코예술극장</prfnmfct>
# </prfst>]
# 20180404
# [<prfst>
# <seatcnt>600</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>77</totnmrs>
# <prfnmplc>대극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>아르코예술극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>110</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>222</totnmrs>
# <prfnmplc>소극장</prfnmplc>
# <prfdtcnt>7</prfdtcnt>
# <prfnmfct>아르코예술극장</prfnmfct>
# </prfst>]
# 20180405
# [<prfst>
# <seatcnt>600</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>107</totnmrs>
# <prfnmplc>대극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>아르코예술극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>110</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>185</totnmrs>
# <prfnmplc>소극장</prfnmplc>
# <prfdtcnt>7</prfdtcnt>
# <prfnmfct>아르코예술극장</prfnmfct>
# </prfst>]
# 20180406
# [<prfst>
# <seatcnt>600</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>48</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>대극장</prfnmplc>
# <prfnmfct>아르코예술극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>110</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>273</totnmrs>
# <prfdtcnt>7</prfdtcnt>
# <prfnmplc>소극장</prfnmplc>
# <prfnmfct>아르코예술극장</prfnmfct>
# </prfst>]
# 20180407
# [<prfst>
# <seatcnt>600</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>109</totnmrs>
# <prfnmplc>대극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>아르코예술극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>110</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>342</totnmrs>
# <prfnmplc>소극장</prfnmplc>
# <prfdtcnt>7</prfdtcnt>
# <prfnmfct>아르코예술극장</prfnmfct>
# </prfst>]
# 20180408
# [<prfst>
# <seatcnt>600</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>113</totnmrs>
# <prfnmplc>대극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>아르코예술극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>110</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>330</totnmrs>
# <prfnmplc>소극장</prfnmplc>
# <prfdtcnt>7</prfdtcnt>
# <prfnmfct>아르코예술극장</prfnmfct>
# </prfst>]
# 20180409
# []
# 20180410
# []
# 20180411
# []
# 20180412
# []
# 20180413
# [<prfst>
# <seatcnt>600</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>225</totnmrs>
# <prfnmplc>대극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>아르코예술극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>110</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>소극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>소극장</prfnmfct>
# </prfst>]
# 20180414
# [<prfst>
# <seatcnt>600</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>72</totnmrs>
# <prfnmplc>대극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>아르코예술극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>110</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>소극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>소극장</prfnmfct>
# </prfst>]
# 20180415
# []
# 20180416
# []
# 20180417
# []
# 20180418
# [<prfst>
# <seatcnt>600</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>10</totnmrs>
# <prfnmplc>대극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>아르코예술극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>110</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>소극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>소극장</prfnmfct>
# </prfst>]
# 20180419
# []
# 20180420
# [<prfst>
# <seatcnt>600</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>26</totnmrs>
# <prfnmplc>대극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>아르코예술극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>110</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>소극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>소극장</prfnmfct>
# </prfst>]
# 20180421
# []
# 20180422
# [<prfst>
# <seatcnt>600</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>10</totnmrs>
# <prfnmplc>대극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>아르코예술극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>110</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>소극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>소극장</prfnmfct>
# </prfst>]
# 20180423
# []
# 20180424
# []
# 20180425
# [<prfst>
# <seatcnt>600</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>10</totnmrs>
# <prfnmplc>대극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>아르코예술극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>110</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>19</totnmrs>
# <prfnmplc>소극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>아르코예술극장</prfnmfct>
# </prfst>]
# 20180426
# [<prfst>
# <seatcnt>600</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>대극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>대극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>110</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>17</totnmrs>
# <prfnmplc>소극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>아르코예술극장</prfnmfct>
# </prfst>]
# 20180427
# [<prfst>
# <seatcnt>600</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>10</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>대극장</prfnmplc>
# <prfnmfct>아르코예술극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>110</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>14</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>소극장</prfnmplc>
# <prfnmfct>아르코예술극장</prfnmfct>
# </prfst>]
# 20180428
# [<prfst>
# <seatcnt>600</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>대극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>대극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>110</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>32</totnmrs>
# <prfnmplc>소극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>아르코예술극장</prfnmfct>
# </prfst>]
# 20180429
# [<prfst>
# <seatcnt>600</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>10</totnmrs>
# <prfnmplc>대극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>아르코예술극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>110</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>24</totnmrs>
# <prfnmplc>소극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>아르코예술극장</prfnmfct>
# </prfst>]
# 20180430
# []
# 20180501
# []

# %% [markdown]
# ## 샤롯데 씨어터

# %%
start = "20180401"
last = "20180501"
start_date = datetime.strptime(start, "%Y%m%d")
last_date = datetime.strptime(last, "%Y%m%d")

# %%
#인증키 입력
encoding ='3618439972f548dd99831f9a6e4856e1' #발급받은 인코딩키 입력
# 종료일 까지 반복
while start_date <= last_date:
    string = str(start_date.year)
    if (start_date.month<10):
        string = string + str(0)
        string = string + str(start_date.month)
    else:
        string = string + str(start_date.month)
    if (start_date.day<10):
        string = string + str(0)
        string = string + str(start_date.day)
    else:
        string = string + str(start_date.day)
    print(string)
    #url 입력
    url = 'https://www.kopis.or.kr/openApi/restful/prfstsPrfByFct?'
    params ={'service' : encoding , 'cpage' : '1', 'rows' : '10', 'stdate' : string, 'eddate' : string,'sharea':'11','shprfnmfct':'샤롯데씨어터' }

    response = requests.get(url, params=params)

    content = response.text

    xml_obj = bs4.BeautifulSoup(content,'lxml-xml')
    rows = xml_obj.findAll('prfst')
    print(rows)

    # xml 안의 데이터 수집
    for item in rows:
        seatcnt = item.find('seatcnt') #좌석 수
        seatcnt = seatcnt.get_text()
        totnmrs = item.find('totnmrs') #총 티켓 판매 수
        totnmrs = totnmrs.get_text()
        data = [seatcnt,totnmrs]
        datas.append(data)

    df = pd.DataFrame(datas, columns=['좌석 수', '티켓 판매수'])
    start_date += timedelta(days=1)
# Out:
# 20180401
# [<prfst>
# <seatcnt>1230</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>121</totnmrs>
# <prfnmplc>샤롯데씨어터</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>샤롯데씨어터</prfnmfct>
# </prfst>]
# 20180402
# []
# 20180403
# [<prfst>
# <seatcnt>1230</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>31</totnmrs>
# <prfnmplc>샤롯데씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>샤롯데씨어터</prfnmfct>
# </prfst>]
# 20180404
# [<prfst>
# <seatcnt>1230</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>66</totnmrs>
# <prfdtcnt>2</prfdtcnt>
# <prfnmplc>샤롯데씨어터</prfnmplc>
# <prfnmfct>샤롯데씨어터</prfnmfct>
# </prfst>]
# 20180405
# [<prfst>
# <seatcnt>1230</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>29</totnmrs>
# <prfnmplc>샤롯데씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>샤롯데씨어터</prfnmfct>
# </prfst>]
# 20180406
# [<prfst>
# <seatcnt>1230</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>25</totnmrs>
# <prfnmplc>샤롯데씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>샤롯데씨어터</prfnmfct>
# </prfst>]
# 20180407
# [<prfst>
# <seatcnt>1230</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>141</totnmrs>
# <prfdtcnt>2</prfdtcnt>
# <prfnmplc>샤롯데씨어터</prfnmplc>
# <prfnmfct>샤롯데씨어터</prfnmfct>
# </prfst>]
# 20180408
# [<prfst>
# <seatcnt>1230</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>110</totnmrs>
# <prfnmplc>샤롯데씨어터</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>샤롯데씨어터</prfnmfct>
# </prfst>]
# 20180409
# []
# 20180410
# [<prfst>
# <seatcnt>1230</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>44</totnmrs>
# <prfnmplc>샤롯데씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>샤롯데씨어터</prfnmfct>
# </prfst>]
# 20180411
# [<prfst>
# <seatcnt>1230</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>47</totnmrs>
# <prfnmplc>샤롯데씨어터</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>샤롯데씨어터</prfnmfct>
# </prfst>]
# 20180412
# [<prfst>
# <seatcnt>1230</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>29</totnmrs>
# <prfnmplc>샤롯데씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>샤롯데씨어터</prfnmfct>
# </prfst>]
# 20180413
# [<prfst>
# <seatcnt>1230</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>36</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>샤롯데씨어터</prfnmplc>
# <prfnmfct>샤롯데씨어터</prfnmfct>
# </prfst>]
# 20180414
# [<prfst>
# <seatcnt>1230</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>150</totnmrs>
# <prfnmplc>샤롯데씨어터</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>샤롯데씨어터</prfnmfct>
# </prfst>]
# 20180415
# [<prfst>
# <seatcnt>1230</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>92</totnmrs>
# <prfnmplc>샤롯데씨어터</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>샤롯데씨어터</prfnmfct>
# </prfst>]
# 20180416
# []
# 20180417
# [<prfst>
# <seatcnt>1230</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>47</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>샤롯데씨어터</prfnmplc>
# <prfnmfct>샤롯데씨어터</prfnmfct>
# </prfst>]
# 20180418
# [<prfst>
# <seatcnt>1230</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>64</totnmrs>
# <prfnmplc>샤롯데씨어터</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>샤롯데씨어터</prfnmfct>
# </prfst>]
# 20180419
# [<prfst>
# <seatcnt>1230</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>41</totnmrs>
# <prfnmplc>샤롯데씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>샤롯데씨어터</prfnmfct>
# </prfst>]
# 20180420
# [<prfst>
# <seatcnt>1230</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>22</totnmrs>
# <prfnmplc>샤롯데씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>샤롯데씨어터</prfnmfct>
# </prfst>]
# 20180421
# [<prfst>
# <seatcnt>1230</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>166</totnmrs>
# <prfdtcnt>2</prfdtcnt>
# <prfnmplc>샤롯데씨어터</prfnmplc>
# <prfnmfct>샤롯데씨어터</prfnmfct>
# </prfst>]
# 20180422
# [<prfst>
# <seatcnt>1230</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>111</totnmrs>
# <prfnmplc>샤롯데씨어터</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>샤롯데씨어터</prfnmfct>
# </prfst>]
# 20180423
# []
# 20180424
# [<prfst>
# <seatcnt>1230</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>51</totnmrs>
# <prfnmplc>샤롯데씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>샤롯데씨어터</prfnmfct>
# </prfst>]
# 20180425
# [<prfst>
# <seatcnt>1230</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>77</totnmrs>
# <prfnmplc>샤롯데씨어터</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>샤롯데씨어터</prfnmfct>
# </prfst>]
# 20180426
# [<prfst>
# <seatcnt>1230</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>51</totnmrs>
# <prfnmplc>샤롯데씨어터</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>샤롯데씨어터</prfnmfct>
# </prfst>]
# 20180427
# [<prfst>
# <seatcnt>1230</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>96</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>샤롯데씨어터</prfnmplc>
# <prfnmfct>샤롯데씨어터</prfnmfct>
# </prfst>]
# 20180428
# []
# 20180429
# [<prfst>
# <seatcnt>1230</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>104</totnmrs>
# <prfnmplc>샤롯데씨어터</prfnmplc>
# <prfdtcnt>2</prfdtcnt>
# <prfnmfct>샤롯데씨어터</prfnmfct>
# </prfst>]
# 20180430
# []
# 20180501
# [<prfst>
# <seatcnt>1230</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>83</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>샤롯데씨어터</prfnmplc>
# <prfnmfct>샤롯데씨어터</prfnmfct>
# </prfst>]

# %% [markdown]
# ## 국립극장

# %%
start = "20190401"
last = "20190501"
start_date = datetime.strptime(start, "%Y%m%d")
last_date = datetime.strptime(last, "%Y%m%d")

# %%
#인증키 입력
encoding ='3618439972f548dd99831f9a6e4856e1' #발급받은 인코딩키 입력
# 종료일 까지 반복
while start_date <= last_date:
    string = str(start_date.year)
    if (start_date.month<10):
        string = string + str(0)
        string = string + str(start_date.month)
    else:
        string = string + str(start_date.month)
    if (start_date.day<10):
        string = string + str(0)
        string = string + str(start_date.day)
    else:
        string = string + str(start_date.day)
    print(string)
    #url 입력
    url = 'https://www.kopis.or.kr/openApi/restful/prfstsPrfByFct?'
    params ={'service' : encoding , 'cpage' : '1', 'rows' : '10', 'stdate' : string, 'eddate' : string,'sharea':'11','shprfnmfct':'국립극장' }

    response = requests.get(url, params=params)

    content = response.text

    xml_obj = bs4.BeautifulSoup(content,'lxml-xml')
    rows = xml_obj.findAll('prfst')
    print(rows)

    # xml 안의 데이터 수집
    for item in rows:
        seatcnt = item.find('seatcnt') #좌석 수
        seatcnt = seatcnt.get_text()
        totnmrs = item.find('totnmrs') #총 티켓 판매 수
        totnmrs = totnmrs.get_text()
        data = [seatcnt,totnmrs]
        datas.append(data)

    df = pd.DataFrame(datas, columns=['좌석 수', '티켓 판매수'])
    start_date += timedelta(days=1)
# Out:
# 20190401
# []
# 20190402
# []
# 20190403
# []
# 20190404
# []
# 20190405
# [<prfst>
# <seatcnt>627</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>하늘극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>하늘극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>별오름극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>별오름극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1221</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>해오름극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>해오름극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>512</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>442</totnmrs>
# <prfnmplc>달오름극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>국립극장</prfnmfct>
# </prfst>]
# 20190406
# [<prfst>
# <seatcnt>627</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>하늘극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>하늘극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>별오름극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>별오름극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1221</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>해오름극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>해오름극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>512</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>437</totnmrs>
# <prfnmplc>달오름극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>국립극장</prfnmfct>
# </prfst>]
# 20190407
# [<prfst>
# <seatcnt>627</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>하늘극장</prfnmplc>
# <prfnmfct>하늘극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>별오름극장</prfnmplc>
# <prfnmfct>별오름극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1221</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>해오름극장</prfnmplc>
# <prfnmfct>해오름극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>512</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>448</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>달오름극장</prfnmplc>
# <prfnmfct>국립극장</prfnmfct>
# </prfst>]
# 20190408
# []
# 20190409
# [<prfst>
# <seatcnt>627</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>하늘극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>하늘극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>별오름극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>별오름극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1221</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>해오름극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>해오름극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>512</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>476</totnmrs>
# <prfnmplc>달오름극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>국립극장</prfnmfct>
# </prfst>]
# 20190410
# [<prfst>
# <seatcnt>627</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>449</totnmrs>
# <prfnmplc>하늘극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>국립극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>별오름극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>별오름극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1221</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>해오름극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>해오름극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>512</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>467</totnmrs>
# <prfnmplc>달오름극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>국립극장</prfnmfct>
# </prfst>]
# 20190411
# [<prfst>
# <seatcnt>627</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>하늘극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>하늘극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>별오름극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>별오름극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1221</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>해오름극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>해오름극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>512</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>458</totnmrs>
# <prfnmplc>달오름극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>국립극장</prfnmfct>
# </prfst>]
# 20190412
# [<prfst>
# <seatcnt>627</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>하늘극장</prfnmplc>
# <prfnmfct>하늘극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>별오름극장</prfnmplc>
# <prfnmfct>별오름극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1221</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>해오름극장</prfnmplc>
# <prfnmfct>해오름극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>512</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>449</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>달오름극장</prfnmplc>
# <prfnmfct>국립극장</prfnmfct>
# </prfst>]
# 20190413
# [<prfst>
# <seatcnt>627</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>하늘극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>하늘극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>별오름극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>별오름극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1221</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>해오름극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>해오름극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>512</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>467</totnmrs>
# <prfnmplc>달오름극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>국립극장</prfnmfct>
# </prfst>]
# 20190414
# [<prfst>
# <seatcnt>627</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>하늘극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>하늘극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>별오름극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>별오름극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1221</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>해오름극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>해오름극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>512</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>462</totnmrs>
# <prfnmplc>달오름극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>국립극장</prfnmfct>
# </prfst>]
# 20190415
# []
# 20190416
# []
# 20190417
# []
# 20190418
# []
# 20190419
# []
# 20190420
# [<prfst>
# <seatcnt>627</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>423</totnmrs>
# <prfnmplc>하늘극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>국립극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>별오름극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>별오름극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1221</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>해오름극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>해오름극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>512</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>달오름극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>달오름극장</prfnmfct>
# </prfst>]
# 20190421
# []
# 20190422
# []
# 20190423
# []
# 20190424
# []
# 20190425
# [<prfst>
# <seatcnt>627</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>하늘극장</prfnmplc>
# <prfnmfct>하늘극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>별오름극장</prfnmplc>
# <prfnmfct>별오름극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1221</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfdtcnt>0</prfdtcnt>
# <prfnmplc>해오름극장</prfnmplc>
# <prfnmfct>해오름극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>512</seatcnt>
# <prfprocnt>1</prfprocnt>
# <totnmrs>357</totnmrs>
# <prfdtcnt>1</prfdtcnt>
# <prfnmplc>달오름극장</prfnmplc>
# <prfnmfct>국립극장</prfnmfct>
# </prfst>]
# 20190426
# [<prfst>
# <seatcnt>627</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>하늘극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>하늘극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>별오름극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>별오름극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1221</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>해오름극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>해오름극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>512</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>410</totnmrs>
# <prfnmplc>달오름극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>국립극장</prfnmfct>
# </prfst>]
# 20190427
# [<prfst>
# <seatcnt>627</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>하늘극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>하늘극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>100</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>별오름극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>별오름극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>1221</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>0</totnmrs>
# <prfnmplc>해오름극장</prfnmplc>
# <prfdtcnt>0</prfdtcnt>
# <prfnmfct>해오름극장</prfnmfct>
# </prfst>, <prfst>
# <seatcnt>512</seatcnt>
# <prfprocnt>0</prfprocnt>
# <totnmrs>325</totnmrs>
# <prfnmplc>달오름극장</prfnmplc>
# <prfdtcnt>1</prfdtcnt>
# <prfnmfct>국립극장</prfnmfct>
# </prfst>]
# 20190428
# []
# 20190429
# []
# 20190430
# []
# 20190501
# []

# %%
df
# Out:
#       좌석 수 티켓 판매수
# 0     1004      0
# 1      354      0
# 2     2527      0
# 3      241    412
# 4      600      0
# ...    ...    ...
# 1037   512    410
# 1038   627      0
# 1039   100      0
# 1040  1221      0
# 1041   512    325
#
# [1042 rows x 2 columns]

# %%
df = df.astype({'티켓 판매수':'int'})

# %%
df_remove = df[df['티켓 판매수']>0]

# %%
df_remove
# Out:
#       좌석 수  티켓 판매수
# 3      241     412
# 5     2283    1011
# 12     241     453
# 14    2283     915
# 21     241     401
# ...    ...     ...
# 1025   512     462
# 1026   627     423
# 1033   512     357
# 1037   512     410
# 1041   512     325
#
# [316 rows x 2 columns]

# %%
df_remove.to_csv('D:\\data.csv')
