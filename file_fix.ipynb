# %%
import pandas as pd
import numpy as np
from datetime import datetime, date ,timedelta

# %%
df = pd.read_csv('올림픽공원 대관 데이터.csv', encoding='cp949')

# %%
df
# Out:
#       DK_JS  DK_SS   DK_NAME DK_BRIEF_NAME EVENT_GUBUN  \
# 0         1      7   우리금융아트홀         제3체육관        체육행사
# 1         1      9      올림픽홀          올림픽홀        대중공연
# 2         1      5    핸드볼경기장        핸드볼경기장      문화예술행사
# 3         1     25     만남의광장         만남의광장        공공행사
# 4         1      9      올림픽홀          올림픽홀        대중공연
# ...     ...    ...       ...           ...         ...
# 3681      1     33  88호수수변무대          88호수      문화예술행사
# 3682      1     10     뮤즈라이브         뮤즈라이브      문화예술행사
# 3683      1     33  88호수수변무대          88호수      문화예술행사
# 3684      1      9      올림픽홀          올림픽홀      문화예술행사
# 3685      1      9      올림픽홀          올림픽홀      문화예술행사
#
#                                       EVENT_NAME  RENT_START_YMD  \
# 0                                 7330노인건강체조경연대회        20150917
# 1     Hiphop PARYY - 딘, 크러시, 자이언티 / DJ. DOC, 코요테        20170418
# 2                    2017 조항조 장윤정 첫번째 콘서트 - 서울공연        20170324
# ...

# %%
df = df[df['RENT_START_YMD']>20170000]

# %%
df
# Out:
#       DK_JS  DK_SS   DK_NAME DK_BRIEF_NAME EVENT_GUBUN  \
# 1         1      9      올림픽홀          올림픽홀        대중공연
# 2         1      5    핸드볼경기장        핸드볼경기장      문화예술행사
# 3         1     25     만남의광장         만남의광장        공공행사
# 4         1      9      올림픽홀          올림픽홀        대중공연
# 5         1      9      올림픽홀          올림픽홀        대중공연
# ...     ...    ...       ...           ...         ...
# 3681      1     33  88호수수변무대          88호수      문화예술행사
# 3682      1     10     뮤즈라이브         뮤즈라이브      문화예술행사
# 3683      1     33  88호수수변무대          88호수      문화예술행사
# 3684      1      9      올림픽홀          올림픽홀      문화예술행사
# 3685      1      9      올림픽홀          올림픽홀      문화예술행사
#
#                                       EVENT_NAME  RENT_START_YMD  \
# 1     Hiphop PARYY - 딘, 크러시, 자이언티 / DJ. DOC, 코요테        20170418
# 2                    2017 조항조 장윤정 첫번째 콘서트 - 서울공연        20170324
# 3                                  2017서울국제마라톤대회        20170318
# ...

# %%
df['Covid'] = 0
df.loc[(df['RENT_START_YMD'] > 20200301) & (df['RENT_START_YMD'] < 20211025), 'Covid'] = 1
# Out:
# C:\Users\dayeo\AppData\Local\Temp\ipykernel_32644\4100846661.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Covid'] = 0

# %%
df
# Out:
#       DK_JS  DK_SS   DK_NAME DK_BRIEF_NAME EVENT_GUBUN  \
# 1         1      9      올림픽홀          올림픽홀        대중공연
# 2         1      5    핸드볼경기장        핸드볼경기장      문화예술행사
# 3         1     25     만남의광장         만남의광장        공공행사
# 4         1      9      올림픽홀          올림픽홀        대중공연
# 5         1      9      올림픽홀          올림픽홀        대중공연
# ...     ...    ...       ...           ...         ...
# 3681      1     33  88호수수변무대          88호수      문화예술행사
# 3682      1     10     뮤즈라이브         뮤즈라이브      문화예술행사
# 3683      1     33  88호수수변무대          88호수      문화예술행사
# 3684      1      9      올림픽홀          올림픽홀      문화예술행사
# 3685      1      9      올림픽홀          올림픽홀      문화예술행사
#
#                                       EVENT_NAME  RENT_START_YMD  \
# 1     Hiphop PARYY - 딘, 크러시, 자이언티 / DJ. DOC, 코요테        20170418
# 2                    2017 조항조 장윤정 첫번째 콘서트 - 서울공연        20170324
# 3                                  2017서울국제마라톤대회        20170318
# ...

# %%
df.to_csv("remove_data.csv", mode='w')
